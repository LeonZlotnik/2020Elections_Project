# %%
import pandas as pd

x = "census_study.csv"

df_one = pd.read_csv(x, encoding="ISO-8859-1")
df_one.head()
# Out:
#    state_name  Total state ethnicity  White Avg  Black Avg  Asian Avg  \
# 0     Alabama              4779736.0  68.526672  26.179500   1.121296
# 1      Alaska               710231.0  66.679151   3.275413   5.369380
# 2     Arizona              6392017.0  73.014840   4.052054   2.764307
# 3    Arkansas              2915918.0  76.999045  15.428932   1.238101
# 4  California             37253956.0  57.588338   6.171350  13.048297
#
#    Latino Avg  Population  Median Age  Household Income  Per Capita Income  \
# 0    1.402567   4799277.0        38.1           43253.0            23680.0
# 1    6.657834    720316.0        33.6           70760.0            32651.0
# 2    3.176806   6479703.0        36.3           49774.0            25358.0
# 3    1.860580   2933369.0        37.5           40768.0            22170.0
# 4    4.492143  37659181.0        35.4           61094.0            29527.0
#
#    Poverty Count  Poverty Rate
# 0       870631.0     18.140878
# ...

# %%
df_one.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>state_name</th>\n      <th>Total state ethnicity</th>\n      <th>White Avg</th>\n      <th>Black Avg</th>\n      <th>Asian Avg</th>\n      <th>Latino Avg</th>\n      <th>Population</th>\n      <th>Median Age</th>\n      <th>Household Income</th>\n      <th>Per Capita Income</th>\n      <th>Poverty Count</th>\n      <th>Poverty Rate</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Alabama</td>\n      <td>4779736.0</td>\n      <td>68.526672</td>\n      <td>26.179500</td>\n      <td>1.121296</td>\n      <td>1.402567</td>\n      <td>4799277.0</td>\n      <td>38.1</td>\n      <td>43253.0</td>\n      <td>23680.0</td>\n      <td>870631.0</td>\n      <td>18.140878</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Alaska</td>\n      <td>710231.0</td>\n      <td>66.679151</td>\n      <td>3.275413</td>\n      <td>5.369380</td>\n      <td>6.657834</t
# ...

# %%
df_one.replace('\n', '')
# Out:
#               state_name  Total state ethnicity  White Avg  Black Avg  \
# 0                Alabama              4779736.0  68.526672  26.179500
# 1                 Alaska               710231.0  66.679151   3.275413
# 2                Arizona              6392017.0  73.014840   4.052054
# 3               Arkansas              2915918.0  76.999045  15.428932
# 4             California             37253956.0  57.588338   6.171350
# 5              Louisiana              4533372.0  62.562525  32.037874
# 6               Kentucky              4339367.0  87.790155   7.778093
# 7               Colorado              5029196.0  81.309259   4.011317
# 8            Connecticut              3574097.0  77.569523  10.136714
# 9               Delaware               897934.0  68.893371  21.361704
# 10  District of Columbia               601723.0  38.468033  50.708549
# 11               Florida             18801310.0  75.043505  15.955601
# ...

# %%
df_one.to_html('census.html')

# %%
# !open census.html

# %%
y = "chip_change.csv"

df_two= pd.read_csv(y, encoding="ISO-8859-1")
df_two.head()
# Out:
#   state_name        date     lat       lon state_abbrev  month_y   chip_x  \
# 0     Alaska  2017-06-01  61.385 -152.2683           AK  2017-06  12454.0
# 1     Alaska  2017-07-01  61.385 -152.2683           AK  2017-06  12605.0
# 2     Alaska  2017-08-01  61.385 -152.2683           AK  2017-06  12763.0
# 3     Alaska  2017-09-01  61.385 -152.2683           AK  2017-06  12602.0
# 4     Alaska  2017-10-01  61.385 -152.2683           AK  2017-06  12963.0
#
#   chip_change
# 0       0.00%
# 1       1.21%
# 2       2.48%
# 3       1.19%
# 4       4.09%

# %%
main_df = df_two.merge(df_one, how='outer', on='state_name')

# %%
main_df.head()
# Out:
#   state_name        date     lat       lon state_abbrev  month_y   chip_x  \
# 0     Alaska  2017-06-01  61.385 -152.2683           AK  2017-06  12454.0
# 1     Alaska  2017-07-01  61.385 -152.2683           AK  2017-06  12605.0
# 2     Alaska  2017-08-01  61.385 -152.2683           AK  2017-06  12763.0
# 3     Alaska  2017-09-01  61.385 -152.2683           AK  2017-06  12602.0
# 4     Alaska  2017-10-01  61.385 -152.2683           AK  2017-06  12963.0
#
#   chip_change  Total state ethnicity  White Avg  Black Avg  Asian Avg  \
# 0       0.00%               710231.0  66.679151   3.275413    5.36938
# 1       1.21%               710231.0  66.679151   3.275413    5.36938
# 2       2.48%               710231.0  66.679151   3.275413    5.36938
# 3       1.19%               710231.0  66.679151   3.275413    5.36938
# 4       4.09%               710231.0  66.679151   3.275413    5.36938
#
#    Latino Avg  Population  Median Age  Household Income  Per Capita Income  \
# ...

# %%
main_df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>state_name</th>\n      <th>date</th>\n      <th>lat</th>\n      <th>lon</th>\n      <th>state_abbrev</th>\n      <th>month_y</th>\n      <th>chip_x</th>\n      <th>chip_change</th>\n      <th>Total state ethnicity</th>\n      <th>White Avg</th>\n      <th>Black Avg</th>\n      <th>Asian Avg</th>\n      <th>Latino Avg</th>\n      <th>Population</th>\n      <th>Median Age</th>\n      <th>Household Income</th>\n      <th>Per Capita Income</th>\n      <th>Poverty Count</th>\n      <th>Poverty Rate</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Alaska</td>\n      <td>2017-06-01</td>\n      <td>61.3850</td>\n      <td>-152.2683</td>\n      <td>AK</td>\n      <td>2017-06</td>\n      <td>12454.0</td>\n      <td>0.00%</td>\n      <td>710231.0</td>\n      <td>66.679151</td>\n      <td>3.275413</td>\n      <td>5.369380</td>\n      <td>6.657834</td>\n  
# ...

# %%
main_df.replace('\n', '')
# Out:
#          state_name        date      lat       lon state_abbrev  month_y  \
# 0            Alaska  2017-06-01  61.3850 -152.2683           AK  2017-06
# 1            Alaska  2017-07-01  61.3850 -152.2683           AK  2017-06
# 2            Alaska  2017-08-01  61.3850 -152.2683           AK  2017-06
# 3            Alaska  2017-09-01  61.3850 -152.2683           AK  2017-06
# 4            Alaska  2017-10-01  61.3850 -152.2683           AK  2017-06
# 5            Alaska  2017-11-01  61.3850 -152.2683           AK  2017-06
# 6            Alaska  2017-12-01  61.3850 -152.2683           AK  2017-06
# 7            Alaska  2018-01-01  61.3850 -152.2683           AK  2017-06
# 8            Alaska  2018-02-01  61.3850 -152.2683           AK  2017-06
# 9            Alaska  2018-03-01  61.3850 -152.2683           AK  2017-06
# 10           Alaska  2018-04-01  61.3850 -152.2683           AK  2017-06
# 11           Alaska  2018-05-01  61.3850 -152.2683           AK  2017-06
# ...

# %%
main_df.to_html('table.html')

# %%
# !open table.html
